# %% [markdown]
# # 机器学习--1分布和有监督学习
#
# ddddyf 开始于7/20/2024
#
# ## 前言
# 本文希望记录个人的学习笔记。
# 原意是想系统地介绍回归和分类的，但是由于想起在暑假的生存分析课堂上所遇到的各种系数的分布，觉得需要学一些正态分布之外的分布类型。
# 列一下三大板块要学的东西：
#
# 分布：正态分布与假设检验、t分布、weibull分布、卡方分布、伽马分布、指数分布、F分布、对数正态分布、泊松分布。
#
# 回归：1.基础：极大似然法、线性回归的四大前提条件与参数估计；2.优化：正则化、梯度下降法和全局最小值搜索；3.评估验证：参数的置信区间、协变量筛选、线性比较系数的假设检验、似然比检验、f检验；4.模型扩展：交互项、中介效应、自相关、过拟合与正则化；5.诊断和特殊情况：未观察到的异质性、数据异常值检验、非参数半参数与非线性回归。
#
# 分类：1.逻辑斯蒂回归；2.决策树；3.随机森林

# %% [markdown]
# ## 一.分布
#
#
# ### 1.什么是分布
#
# 分布是基于概率产生的概念。一个随机变量可能取不同的值，我们希望了解它在取不同的值有多少的概率。一般来说，变量需要满足“独立同分布”假设。
#
# **PDF函数(probability density function)** ：概率密度函数。对于连续型变量，取任一具体值的概率为零。
#
# **CDF函数(cunmulative distribution function)** ：累积分布函数。$CDF(x)=\int_{-\infty}^{x}PDF(u)du$。函数值表示随机变量小于等于该值的概率。该函数亦可以计算取值落在某一范围内的概率。
#
#
# ### 2.正态分布
#
# 正态分布的来源：中心极限定理。假设在总体中抽取样本量为n＞30的样本，它的均值为$\bar{x}$,进行多次抽样，可以发现$\bar{x}$服从正态分布。
#
# PDF函数: $f(x) = \frac{1}{\sigma\sqrt{2\pi}} e^{-\frac{(x-\mu)^2}{2\sigma^2}}$。
#
# 我们可以对x进行“标准化”处理，这样把任何变量转化为一个服从同一个分布函数的变量，可以利用一个分布函数解决所有正态分布的问题。首先“中心化”，将平均值作为原点：$x_i^{\prime}=x_i-\bar{x_i}$, 除以标准差：$x_i^{\prime\prime}=\frac{x_i^{\prime}}{\sigma}$。经过这样一番操作后，新的变量均值为0，标准差为1。 称该分布为标准正态分布：
#
# $\mu=0$, $\sigma=1$， $f(x) = \frac{1}{\sqrt{2\pi}} e^{-\frac{x^2}{2}}$、
#
# **重要性质：**正态分布的线性组合仍为正态分布。
#
# #### 代码实现：检验数据正态性

# %%
#图像法
import numpy as np  
import matplotlib.pyplot as plt  
  
data = np.random.normal(loc=0, scale=1, size=1000)  # 生成正态分布的随机数据  
  
plt.hist(data, bins=30, density=True, alpha=0.6, color=['#808080'])  
xmin, xmax = plt.xlim()  
x = np.linspace(xmin, xmax, 100)  
p = np.exp(-(x - 0)**2 / 2) / np.sqrt(2 * np.pi)  
plt.plot(x, p, 'k', linewidth=2)  
plt.show()

# Shapiro-Wilk检验
from scipy import stats
  
stat, p = stats.shapiro(data)  
print('Statistics=%.3f, p=%.3f' % (stat, p))  
 
alpha = 0.05  
if p > alpha:  
    print('样本看起来是正态分布的 (fail to reject H0)')  
else:  
    print('样本不是正态分布的 (reject H0)')

# %% [markdown]
# ### 3.假设检验
#
# 有零假设$H_0$，在该假设下，计算所构造的统计量出现的最大概率$p$，若$p$值过小(如＜0.05)，则认为该假设为小概率事件而予以拒绝;若并不太小，则认为没有充分理由拒绝假设。
#
# 一般这个统计量只有在服从某种分布时才能计算它出现的最大概率。这是我们建立多种分布模型的动机：严格地用数学的模型解释现实数据。
#
#
# ### 4.t分布
#
# 正态分布函数所使用的方差是总体标准差$\sigma$ ，但大多数时候我们只知道样本标准差。使用样本标准差来标准化后，统计量的分布服从t分布。 **这是t分布与正态分布的根本区别。** 但由于随着样本量的增大，s会向$\sigma$逼近，所以在n＞30(或＞45)，且不知道总体方差时，我们可以采用正态分布。而当样本量较小，且总体分布服从正态分布时，使用t分布。这时样本的大小成为一个重要变量，以**自由度** $df=n-1$衡量
#
# t分布的PDF函数由gamma函数推出。
#
#
# ### 5.卡方分布
#
# #### 卡方统计量的构建
# 独立随机变量：$x_1,x_2,...,x_k$服从标准正态分布$N(0,1),X = \sum_{i=1}^k x_i^2$，则$X$服从自由度为$k$的卡方分布$\chi^2(k)$
#
# 其中$E(X) = n, D(X) = 2n$
#
# *卡方分布的**PDF**函数为：$f(x; k) = \frac{x^{\frac{k}{2} - 1} e^{\frac{-x}{2}}}{2^{\frac{k}{2}} \Gamma\left(\frac{k}{2}\right)}$(函数$\Gamma(x)$见伽马分布)*
# #### 卡方检验
# $H_0$:离散型变量A与离散型变量B不存在相关关系。
#
# 列联表记录同时满足$A=A_i, B=B_i$时的频数$O_{ij}$。
# 构造$x_{ij} = \frac{(O_{ij}-E_{ij})^2}{E_{ij}}$，其中，$O_{ij}$为观察值，$E_{ij}$为满足$H_0$的理论值。
# $X = \sum_{i=1,j=1}^{k,s} x_{ij}$，$df=(k-1)(s-1)$，则$X$满足$\chi^2(df)$，将$X$的值代入，可以获得$p$。$X越大，p越小$。若$p$小于0.05可以认为出现了小概率事件，拒绝零假设。
#
#
# ### 6.泊松分布
#
# **PMF**(probability mass function):
#
# $f(X=k)=\frac{e^{-\lambda}{\lambda^k}}{k!}, k=0,1,2,3,...$
#
# 可以检验该式满足分布律的条件：$\sum_{k=0}^{\infty}f(X=k) = e^{-\lambda}\sum_{k=0}^{\infty}\frac{\lambda^k}{k!} = e^{-\lambda}e^\lambda = 1$ 其中，第二步利用了指数函数的麦克劳林展开。
#
# 泊松分布的主要作用是近似模拟二项分布。我们知道当p值在0.5左右，n较大时，由于中心极限定理，可以用正态分布近似二项分布。但当p的值很小时，我们可以用泊松分布。令$\lambda=np$，当$\lambda$为一常数时，因为$\lim_{n\to\infty}\binom{n}{k} p^k (1-p)^{(n-k)} = \frac{\lambda^k e^{-\lambda}}{k!}$只有当$n$取极大值时等号成立，所以$p=\frac{\lambda}{n}$取极小值。即，当$p$很小，$n$很大时，可以用泊松分布模拟二项分布。(可能的标准：$n≥20$，$p≤0.05$)
#
# 可以由$\sum_{k=0}^{\infty}kf(X=k) = \lambda = np$知泊松分布近似后数学期望不变。
#
#
# ### 7.指数分布
#
# 泊松分布可以研究在一定时间内某一服从伯努利分布的事件发生k次的概率（假设固定时间t内发生固定的N次服从伯努利分布的事件），如果我们想研究上一个事件过时间t后发生第二次事件的概率，需要指数分布。
# 利用泊松过程，扩展泊松分布的分布律：
#
# $P(X=k,t) = \frac{({\lambda}t)^k}{k!}e^{-{\lambda}t}$
#
# 由于两次事件发生间隔大于$t$的概率等于在时间$t$内没发生事件的概率：
#
# $P(Y≥t) = P(k=0,t) = e^{-{\lambda}t}$
#
# $\Rightarrow P(Y≤t) = 1-e^{-{\lambda}t}$
#
# $\Rightarrow f(x) = P(Y≤t)^{\prime} = {\lambda}e^{-{\lambda}t}$
#
# 其中$f(x) = {\lambda}e^{-{\lambda}t}$就是指数分布的概率密度函数。还可以知道泊松分布的期望为$\frac{1}{\lambda}$，相当于把“单位时间里发生$\lambda$事件”等价表述为“单位事件之间隔$\frac{1}{\lambda}$事件”。
#
# $E(X) = \frac{1}{\lambda}, D(x) = \frac{1}{{\lambda}^2}$
#
#
# ### 8.伽马分布
#
# 通过泊松分布和指数分布，我们分别解决了单位时间内发生k件事的概率和两件事之间时间间隔为t的概率两个问题。对后者进行拓展，对前者取逆函数得命题：在一定速率$\beta(\frac{1}{\lambda})$下，发生$\alpha$次单位事件的时间为$x$的概率。其中我们把$\alpha$称为形状参数，$\beta$为尺度参数。
#
# 若 $X{\sim}\Gamma(\alpha,\beta)$
#
# **PDF:** $f(x; \alpha, \beta) = \frac{x^{\alpha - 1} e^{\frac{-x}{\beta}}}{\beta^{\alpha} \Gamma(\alpha)}$
#
# 其中，$\Gamma(\alpha)$为伽马函数。
#
# #### 伽马函数
# 解析式：$\Gamma(z) = \int_0^\infty t^{z-1} e^{-t} \, dt$
#
# **性质:**
#
# 1.递推式：$\Gamma(z+1) = z\Gamma(z)$,当$z$为整数时,$\Gamma(z) = (n-1)!$.
#
# 2.欧拉反射公式：$\Gamma(z) \Gamma(1 - z) = \frac{\pi}{\sin(\pi z)}$
#
# 3.特殊值：$\Gamma(\frac{1}{2}) = \sqrt{\pi}$, $\Gamma(\frac{3}{2}) = \frac{\sqrt{\pi}}{2}$
#
# #### 伽马分布的性质
# $E(X) = {\alpha}{\beta} = \frac{\alpha}{\lambda}$, $D(X) = \alpha{\beta}^2$
#
# 当$\alpha=1$时，为指数分布；当$\alpha=\frac{n}{2},\beta=2$时，为卡方分布，其中$n$为自由度（此时$\alpha$和$\beta$不具次数和速率的含义，单纯作为两个调整形状和尺度的参数）。
#
#
# ### 9.F-分布
#
# 为了比较两组数据的方差的差异，我们可以利用F-分布。即如果所构造的F-统计量的$p$值小于阈值，则认为方差显著不同。
#
# #### 为什么要比较方差
# 方差衡量了数据的离散情况，而离散程度越大，数据的相似性越小（即所具有的共同特征越小）。这一想法可以用于分组：如果组内的方差很小，组间的方差很大，就达到了分组的目的：把特征相似的数据集中起来，进而避免其他数据产生噪声干扰。另一方面
#
# #### 如何比较方差
# 假设有两组数据$U_1,U_2$自由度分别为$d_1,d_2$，服从卡方分布，构造F-统计量：
#
# $X = \frac{U_1/d_1}{U_2/d_2}$
#
# 则$X \sim F(d_1,d_2)$
#
# **PDF:**$f(X, d_1, d_2) = \frac{\left(\frac{d_1 x}{d_1 x + d_2}\right)^{d_1/2} \left(\frac{d_2}{d_1 x + d_2}\right)^{d_2/2}}{x B\left(\frac{d_1}{2}, \frac{d_2}{2}\right)}, \quad x > 0$（这个函数可以由卡方分布的概率密度函数推出来），其中$\beta$ 函数$B(x_1,x_2) = \int_0^1 t^{x_1-1} (1-t)^{x_2-1} \, dt = \frac{\Gamma(x_1)\Gamma(x_2)}{\Gamma(x_1+x_2)}$
#
# 其中，当进行组间和组内比较时，$X = \frac{SSB/(k-1)}{SSW/(N-k)}$；$SSB$为组间平方差和，$SSW$为组内平方差和，$k$是分组数，$N$是总样本量。
#
# *当对模型进行回归平方和和残差平方和的比较时，$X = \frac{SSR/k}{SSE/(n-k-1)}$；$SSR$是回归平方和，$SSE$是残差平方和，$k$是除去截距项参数的个数，$n$是样本量。(见回归部分的评估验证）*
#
# 均值：$E(X) = \frac{d_2}{d_2 - 2},d_2＞2$， 方差：$D(X) = \frac{2 \cdot (d_2^2 + d_1 \cdot d_2 - d_1^2)}{d_1 \cdot (d_2 - 2)^2 \cdot (d_2 - 4)},d_2＞4$
#
# $n_2$的值越大，偏态越不明显，因为期望值左移。
#
# 若$Z\sim F(m,n)$，则$\frac{1}{Z}\sim F(n,m)$。
# 若$T\sim t(n)$，则$T^2\sim F(1,n-1)$。(因为样本均值服从正态分布，平方后服从自由度为1的卡方分布；样本方差服从自由度为n-1的卡方分布）
#
#
# ### 10.对数正态分布
#
# **对数为正态分布的随机量服从对数正态分布,服从正态分布的随机量的指数服从对数正态分布。** 服从对数正态分布的统计量一定是正数。
#
# 注意：对数正态分布的PDF函数不是简单地换元为“$lnx$"，应该先对CDF函数进行换元，再对其求导。
#
# $f(y) = \frac{1}{y \sigma \sqrt{2\pi}} \exp\left( -\frac{(\ln y - \mu)^2}{2\sigma^2} \right)$
#
# $E(Y) = e^{\mu + \frac{\sigma^2}{2}}, D(Y) = \left(e^{\sigma^2} - 1\right)e^{2\mu + \sigma^2}$
#
# 有些数据的分布并不平衡，出现“二八定律”的情况，如居民收入，大部分人的收入集中在较低水平，有少部分人的收入非常高。此时相比正态分布，对数正态分布更能描述这类数据，从图像上看，对数正态分布右偏且有长右尾。同样，涉及“寿命”时，也可能服从这个分布：在大多数个体的寿命较短时，仍有小部分的个体寿命极长。
#
# 此外，在考虑“增长”时，每次增长都是对前一次状态的乘积运算，但有时增长率很慢，不易察觉。对增长率取指数，则能放大增长效果，同时把增长体现为加法，更为直观。此时新的表示“增长率”的统计量服从对数正态分布。
#
#
# ### 11.Weibull分布
#
# 指数分布衡量了时间x内发生一次事件的概率，这是相对服从伯努利分布的个体而言的；如果研究对象是一组样本，则应当表述为时间x内发生事件的个体占总体的多少百分比。注意到概率等于这个比例，所以这个量等于$CDF(x)$。
#
# **PDF:** $f(t; \lambda, k) = \frac{k}{\lambda} \left(\frac{t}{\lambda}\right)^{k-1} e^{-(\frac{t}{\lambda})^k}$，
# **CDF:** $F(t; \lambda, k) = 1 - e^{-(t/\lambda)^k}$
#
# $E(X) = \lambda \Gamma\left(1 + \frac{1}{k}\right)$，
# $D(X) = \lambda^2 \left[ \Gamma\left(1 + \frac{2}{k}\right) - \left(\Gamma\left(1 + \frac{1}{k}\right)\right)^2 \right]$
#
# 其中，$\lambda$是比例参数，是$1-e^{-1}$=63.2%的样本失效时的时间。$k$是形状参数，决定失效率随时间变化的模式。$k<1$的情况下，失效率随时间减少，PDF函数单减，适用于早期失效或烧合期；$k>1$的情况下，失效率随时间增加，PDF先增后减，适用于磨损失效或老化期。值得注意的是，当$k=1$时，退化为指数分布，失效率固定。

# %% [markdown]
# ## 二.回归
#
# 回归就是通过样本数据找到因变量与解释变量的量化关系，前提是假设两者之间存在关系，通过回归进行验证和衡量。回归的主要目的是预测结果和分析解释变量的影响。
#
# 日常生活中，我们能观察到很多经验事实。如：服用对乙酰氨基酚可以缓解发热这一现象。从化学角度可以做出因果判断，而通过数据分析可以做出相关性的判断，这是在科研中必要的补充。
#
# ## 1.回归基础
#
# ### 1.极大似然估计
#
# 极大似然估计的目的是求概率分布的参数值。考虑这样一种情况：从一个只有红球和白球的箱子里有放回地随机摸出10个球，发现里面有4个白球，试估计箱子里白球的比例。我们通常是“用样本估计总体”，直接$4\div10=\frac{2}{5}$，但这种说法没有理论支撑。显然，不是这10个球的**样本**特征决定了箱子里**总体**特征，而是**总体**决定了**样本**，这是一个因果关系。所以思路应该是假设箱子里白球的占比$\theta$，每一个$\theta$值都代表一次平行事件，我们采用“摸出4个白球”的概率最大时的$\theta$值作为估计值。为了实现这一设想，我们需要建立**似然函数**。
#
# 似然函数将观测数据固定，而将参数视为变量，评估在不同参数值下观测到这些数据的可能性。**当似然函数有最大值时，取这个$\theta$值**。在这个例子中，参数$\theta$就是箱子里白球的比例，它等于在箱子中随机取，取出白球的概率p。函数$L(p∣\frac{2}{5}) = \binom{10}{4}p^4 (1-p)^6$，经求导计算，当p在0到1之间时，p取$\frac{2}{5}$时似然函数有最大值。
#
# 考虑更一般的情况，观察到独立的服从同一个离散型分布的事件$A_1, A_2,...,A_n$，设该分布的PMF函数为$P_\theta(A)$，其中$\theta$为分布的参数，$P(A_i)=p_i$，则构造似然函数为$L(\theta∣A_1, A_2,...,A_n) = p_1*p_2*...*p_n$。这里的乘法是因为独立事件同时发生的概率等于它们发生的概率乘积。同理可以推广到连续型随机变量上，只需要把PMF换成PDF。
#
# 我们知道求线性回归方程的系数需要用最小二乘法，我们会在后面给予推导。值得注意的是这需要用到极大似然估计。
#
# ### 2.线性回归的三重前提条件
#
# #### 线性回归方程的结构
# $y_i = \beta*X_i + \varepsilon_i$。其中$y_i$是响应变量，$X_i$是解释变量，它是一个包含多个维度数据的向量，$\beta$是参数，也是一个向量。$\varepsilon_i$是误差项。误差项的存在原因可能是公式的解释变量维数少于实际造成影响的解释变量的维数（未观察到的异质性），或测量和数据收集过程中的误差。特别在公式中列出误差项是必要的，这更符合线性回归的实际情况，同时能为判断模型的拟合程度提供帮助。
#
# #### 条件1.满秩性
# 样本量要大于自变量的维数。这是显然的，否则通过解线性方程的知识可以知道系数不唯一(或者说有无穷多解)，方程也自然没有意义。
# #### 条件2.正态性
# 误差项服从正态分布。
# #### 条件3.高斯-马尔可夫条件
# 这是对条件2的进一步补充，包括：
#
# 1.回归模型是自变量与因变量之间的线性关系。这是对方程的形式作出假设。
#
# 2.误差项**独立地**服从**期望为0**的**同方差**正态分布。其中“独立”指$Cov(\varepsilon_i,\varepsilon_j)=0$，即误差项之间没有线性关系。
#
# 3.自变量和误差项之间没有相关性，两者协方差$Cov(\varepsilon_i,X_i)=0$。也就是误差项的分布不受自变量取值的影响。这是需要注意的，因为当存在未观察到的异质性时（如数据存在分组的现象，但并未把这一特征纳入方程），不同的组的误差项服从不同的正态分布，这就违反了第2项的条件。
#
# ### 3.参数估计：从极大似然估计到最小二乘法
# 将用模型表示的预测值$\beta*X_i$减去观测值$y_i$，取它的平方和并令其最小，就可以得到参数$\beta$的估计，此时误差是最小的。但是，为什么是取平方，不是三次方、四次方呢？除了便于计算和去掉负数之外，我们的解释是平方符合极大似然估计。
#
# 假设$\varepsilon$服从$N(0,\sigma^2)$，则$y_i$服从$N(\beta*X_i,\sigma^2)$，$p_i = \frac{1}{\sigma\sqrt{2\pi}} e^{-\frac{(y_i-\beta*X_i)^2}{2\sigma^2}}$。根据我们在第一节的知识，似然方程$L(\beta∣A_1, A_2,...,A_n) = p_1*p_2*...*p_n = \Pi_{i=1}^n\frac{1}{\sigma\sqrt{2\pi}} e^{-\frac{(y_i-\beta*X_i)^2}{2\sigma^2}}$，下面只需让$L$取到最小值。
# 取对数，可表示为$logL = A - B\Sigma_{i=1}^n(y_i-\beta*X_i)^2$，其中$B=\frac{1}{2\sigma^2}$是一个正数。要求这个函数的极大值，就要求后面那组求和式的最小值，这就是最小二乘法的产生。
#
# #### 求参数的值
# 求一个函数达到最小值时自变量的取值，这在高中阶段时一个经典命题。我们不妨用导数的思想求一元线性回归的参数。
#
# 即求$f(a,b)=\Sigma_{i=1}^n(y_i-ax_i-b)^2$取最小值时a和b的取值。展开得$f(a,b)=\Sigma_{i=1}^n(x_i^2a^2+2x_iab+b^2-2x_iy_ia-2y_ib+y_i^2)$，分别对a，b求偏导并令其为零:
#
# \begin{align}
# \frac{\partial f}{\partial a} &= 2(\Sigma x_i^2a+\Sigma x_ib-\Sigma x_iy_i) = 0\\
# \frac{\partial f}{\partial b} &= 2(nb+\Sigma x_ia-\Sigma y_i) = 0
# \end{align}
#
# 可以求得$a = \frac{\Sigma x_iy_i-n\bar{x}\bar{y}}{\Sigma x_i^2-{\bar{x}}^2}$
# ，再由$Heisson$矩阵的行列式$het(H)=4ac-b^2=4n(\Sigma x_i^2-n\bar{x}^2)＞0$(柯西不等式)且$\Sigma x_i＞0$，知道该极值点为最小值点。
#
# 这是中学的方法，在多元线性回归中要把一位的数扩充到多维的向量：
#
# $f(\beta) = Y^TY-2Y^TX\beta+\beta^TX^TX\beta$
#
# $\frac{\partial f}{\partial \beta} = 2(-X^TY+X^TX\beta) = 0$
#
# $X^TX\beta = X^TY$
#
# 这里，我们用线性代数表示的$\beta$的解析解：$\hat{\beta}=(X^TX)^{-1}X^TY$。这里用$\hat{\beta}$是因为这是参数的估计值，不能将其与参数本身混淆。这里，我们还要证明$\hat{\beta}$就是$\beta$的无偏估计。即$\hat{\beta}$的期望等于$\beta$。
# *这里注意要用线性回归的前提：1.误差项独立地服从期望为0的同方差正态分布。2.自变量x和误差项$\varepsilon$之间没有相关性。*
# $
# E(\hat{\beta}) = E((X^TX)^{-1}X^TY) = E((X^TX)^{-1}X^T(X\beta+\varepsilon)) = E((X^TX)^{-1}X^TX\beta)+E((X^TX)^{-1}X^T\varepsilon) = E(\beta)+E((X^TX)^{-1}X^T)E(\varepsilon) = \beta
# $
# 如果想用向量的解析解验证最小二乘的式子。这里假设$X = \begin{pmatrix} x_1 & 1 \\ X_2 & 1 \\ ... & ... \\ x_n & 1 \end{pmatrix}$，则$(X^TX)^{-1} = \frac{1}{n\Sigma x_i^2-n\bar{x}^2}* \begin{pmatrix} n & -n\bar{x} \\ -n\bar{x} & \Sigma x_i^2 \end{pmatrix}$
#
# ### 代码实现
# 下面演示在python中使用线性回归的解析解，并列出样本数据的图表。值得注意的是，sklearn内置的回归算法也是用的解析解求参数，只需要：

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression


data = pd.DataFrame({
    'X1': [1, 2, 3, 4, 5],
    'X2': [2, 3, 6, 8, 12],
    'Y': [4, 7, 11.5, 16, 22]
})
X = data[['X1', 'X2']]
y = data['Y']

model = LinearRegression()
model.fit(X, y)
b = model.intercept_
k1, k2 = model.coef_[0], model.coef_[1]
print(f'弱鸡版：\ny = {k1:.2f}x1 + {k2:.2f}x2 + {b:.2f}')  # 2f的意思是精确度

# 我们下面用第二种方法，会显示更多信息
import statsmodels.api as sm


X = sm.add_constant(X)  # 加上一个截距项
model = sm.OLS(y, X).fit()
print(f'\n牛逼版：\n{model.summary()}')
# Out:
# 弱鸡版：
# y = 1.89x1 + 1.04x2 + -0.04
#
# 牛逼版：
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                     1048.
# Date:                Thu, 08 Aug 2024   Prob (F-statistic):           0.000953
# Time:                        16:03:44   Log-Likelihood:                 1.0074
# No. Observations:                   5   AIC:                             3.985
# Df Residuals:                       2   BIC:                             2.813
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0435      0.424     -0.103      0.928      -1.866       1.779
# ...

# %% [markdown]
# **简单解读一下上表**
# coef是参数值，std err是标准误，t是t统计量，即$\frac{coef}{std err}$，P是在t分布下大于丨coef丨的概率，越小越显著，最后一个是置信区间。当P很大时，说明该参数很有可能为零。
# 不用的现成的函数，我们直接手搓模型。

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt


# 1.生成样本数据
np.random.seed(0)  
X = 2 * np.random.rand(100, 1)  # 100个样本点，特征范围从0到2
y = 4 + 3 * X + np.random.randn(100, 1)  # y = 4 + 3x + 噪声
# 2.打印生成的样本数据
data = {'因变量':y.flatten(), '自变量':X.flatten()}
df_1 = pd.DataFrame(data)
print(df_1)
# 3.使用解析法进行线性回归
X_b = np.c_[np.ones((100, 1)), X]  # 在X前加上一列全1（截距项）
theta_best = np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y  
# 4.提取回归系数和截距
intercept, slope = theta_best[0], theta_best[1]
print(f"\n回归方程: y = {intercept[0]:.2f} + {slope[0]:.2f}x")
# 5.计算R^2
y_pred = X_b @ theta_best
r2 = r2_score(y, y_pred)
print(f"\nR^2值: {r2:.2f}")
# 6.绘制数据点和回归直线
plt.rcParams['font.sans-serif'] = ['SimHei']  # 使用黑体
plt.rcParams['axes.unicode_minus'] = False  # 解决负号 '-' 显示问题
plt.figure(figsize=(3,2), dpi=200)
plt.scatter(X, y, color='#668B8B', s=1.2, label='样本数据')
plt.plot(X, X_b @ theta_best, color='#698B69', linewidth=0.4, label='回归直线',antialiased=True)
plt.xlabel('特征X')
plt.ylabel('目标y')
plt.legend()
plt.title('线性回归演示')
plt.show()
# Out:
#          因变量       自变量
# 0   6.127731  1.097627
# 1   9.191963  1.430379
# 2   8.082243  1.205527
# 3   5.733055  1.089766
# 4   8.030181  0.847310
# ..       ...       ...
# 95  5.780743  0.366383
# 96  6.715668  1.173026
# 97  3.431095  0.040215
# 98  8.518108  1.657880
# 99  4.045652  0.009391
#
# [100 rows x 2 columns]
#
# 回归方程: y = 4.22 + 2.97x
#
# R^2值: 0.75

# %% [markdown]
# **针对代码的说明**
# 这个例子很好地说明了回归系数$\beta=\begin{pmatrix} 3 \\ 4 \end{pmatrix}$和回归系数的估计值$\hat{\beta}=\begin{pmatrix} 2.97 \\ 4.22 \end{pmatrix}$的关系。后者是前者的无偏估计，但为什么最后看来两者的取值并不相等呢。前面说过无偏估计指的是$\hat{\beta}$的期望等于$\beta$，所以算出来的$\hat{\beta}$是服从以$\beta$为均值的正态分布的一个估计值。

# %% [markdown]
# 现实来讲，我们面对的通常是存储在excel中的数据，有时候并不是每一个个体的特征都被充分记录，会出现空值或示意数据性质的代码(如0，1)。下面展示读取excel数据并进行回归的实战,对于空值或表明数据无效的数据会予以排除。

# %%
import pandas as pd
import statsmodels.api as sm


file_path = 'test_regre1.xlsx' 
sheet_name = 'Sheet1' 
df = pd.read_excel(file_path, sheet_name=sheet_name)

# 下面把中文列名改为字母代号
df.rename(columns={'房屋总价(w)': 'Y', '房屋面积(平米)': 'X_1', '房屋楼层': 'X_2', '是否处于城市': 'X_3'}, inplace=True)
#  去除空值和不在城市的数据
df_1 = df[~(df[['Y', 'X_1', 'X_2']].isna().any(axis=1))]  #有空值的会返回TRUE加'~'改变为FALSE。这里会删除一切FALSE的行。
df_1 = df_1[(df_1['X_3'] == 1)]  #删除不在城市的房子

y = df_1['Y']
X = df_1[['X_1', 'X_2']]  
X = sm.add_constant(X)
md = sm.OLS(y,X).fit()
print(md.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 3.001e+04
# Date:                Thu, 08 Aug 2024   Prob (F-statistic):           1.68e-35
# Time:                        15:34:15   Log-Likelihood:                -59.211
# No. Observations:                  23   AIC:                             124.4
# Df Residuals:                      20   BIC:                             127.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8342      2.683      0.311      0.759      -4.762       6.431
# ...

# %% [markdown]
# ## 2.优化
#
# 在求参数的值时我们并不总是用解析法，首先是当矩阵$X$为非满秩时，无法求$X^TX$的逆；其次是矩阵求逆的计算量大，在数据量很大时性能不佳。此外上面所展示的普通最小二乘法不能处理需要对数据进行加权的情况。我们需要更多的求参数方法。
#
# ### 1.加权最小二乘法
#
# 加权最小二乘法是在普通最小二乘法的基础上对数据加以权重来计算回归参数。参数的解析解为$(X^TWX)^{-1}X^TWY$，其中$W$是一个对角矩阵，对角上的元素是每个个体的权重。
#
# 在考虑采用加权最小二乘法时，第一种情况是一部分数据的来源更可靠（测量误差更小、精度更高），我们需要更重视这一部分的数据，所以给予其更大的权重。第二种情况是数据中产生了异方差性。
#
# #### 异方差性
# 异方差性指误差项的方差不为常数，违反了“同方差”的假设。产生的原因之一是模型不完善，未包含应有的自变量，使得误差项随自变量变化。原因之二是数据本身有自发变异，如由于高收入群体的收入波动更大，其方差就会比中间收入的方差更大。
#
# 为了使这些方差不同的数据方差相同，我们需要对其加权。可以对每个个体加不同权重，也可以分组加权，权重都为此个体/组的方差$\sigma_i^2$的倒数。这便满足了同方差的假设；同时，由于方差越大，权重越小，降低了异常值对回归的影响。
#
# 下面这段代码会通过散点图展示具有异方差性的样本特征，并演示加权最小二乘法回归的代码。将其与普通最小二乘法进行对比，并用加权均方误差评估模型。加权均方误差(WMSE)是一种用来在有异方差性存在时衡量模型误差的统计量，其值越小越好。$WMSE = \frac{\Sigma_{i=1}^n w_i(y_i-\hat{y}_i)^2}{\Sigma_{i=1}^n w_i}$。其$R^2$更小，这是正常的。

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# 1.生成样本数据
np.random.seed(0)
X_1 = 2 * np.random.uniform(0,1.5,70)  # 特征
X_2 = 2 * np.random.uniform(1.5,5,30)
y_1 = 4 + 3 * X_1 + np.random.randn(70)*0.5  
y_2 = 4 + 3 * X_2 + np.random.randn(30)*3
X = np.concatenate((X_1,X_2))
y = np.concatenate((y_1,y_2))
average = np.mean(y-4-3*X)
X_b = np.c_[np.ones((100, 1)), X]  # 增加截距项
print('实际回归方程:y = 3x + 4')

# 2.计算残差的平方作为方差估计，并生成权重
residuals = (y-4-3*X-average)**2
estimated_variance = residuals
weights = 1 / (estimated_variance + 1e-8)  # 避免除零错误
W = np.diag(weights.flatten())  # 创建加权矩阵 W

# 3.普通回归
X_b = np.c_[np.ones((100, 1)), X] 
theta_best_1 = np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y  
b_1, k_1 = theta_best_1[0], theta_best_1[1]
print(f"\n普通回归方程: y = {k_1:.2f}x + {b_1:.3f}")
# 计算R^2
y_pred_1 = X_b @ theta_best_1
r2_1 = r2_score(y, y_pred_1)
print(f"R^2值: {r2_1:.4f}")
# 计算加权均方误差（WMSE）
errors_squared = (y - y_pred_1) ** 2  # 计算误差的平方
weighted_errors_squared = weights * errors_squared  # 计算加权后的误差平方
wmse = np.sum(weighted_errors_squared) / np.sum(weights) 
print(f'加权均方误差：{wmse:.6f}')
# 4.加权回归
X_b = np.c_[np.ones((100, 1)), X] 
theta_best_2 = np.linalg.inv(X_b.T @ W @ X_b) @ X_b.T @ W @ y  
b_2, k_2 = theta_best_2[0], theta_best_2[1]
print(f"\n加权回归方程: y = {k_2:.2f}x + {b_2:.3f}")
# 计算R^2
y_pred_2 = X_b @ theta_best_2
r2_2 = r2_score(y, y_pred_2)
print(f"R^2值: {r2_2:.4f}")
# 计算加权均方误差（WMSE）
errors_squared = (y - y_pred_2) ** 2  # 计算误差的平方
weighted_errors_squared = weights * errors_squared  # 计算加权后的误差平方
wmse = np.sum(weighted_errors_squared) / np.sum(weights) 
print(f'加权均方误差：{wmse:.6f}')

# 6.绘制结果
plt.figure(figsize=(6.25, 2.75), dpi=200)  # 提高清晰度
plt.rcParams['font.sans-serif'] = ['SimHei']  # 使用黑体
plt.rcParams['axes.unicode_minus'] = False  # 解决负号 '-' 显示问题
plt.subplot(1, 2, 1)
plt.scatter(X, y, color='#2F4F4F', label='样本点', s=1.25)
# 画回归线
x_line = np.linspace(min(X), max(X), 100)
y_line_1 = k_1 * x_line + b_1
y_line_2 = k_2 * x_line + b_2
plt.plot(x_line, y_line_1, color='#8B658B',linewidth=1, label='普通回归', antialiased=True)  # 抗锯齿
plt.plot(x_line, y_line_2, color='#1E90FF',linewidth=1, label='加权回归', antialiased=True)
plt.xlabel('特征X', fontsize=7.5)
plt.ylabel('目标y', fontsize=7.5)
plt.title('一组在自变量值大时方差更大的数据', fontsize=9)
plt.legend(fontsize=6.5, facecolor='#FFF5EE')  # 为标签栏涂上喜欢的颜色
plt.tight_layout()
plt.show()

# 私认为以上的作图代码可以作为美观的数据可视化的一个例子。
# Out:
# 实际回归方程:y = 3x + 4
#
# 普通回归方程: y = 2.94x + 4.229
# R^2值: 0.9550
# 加权均方误差：0.006207
#
# 加权回归方程: y = 3.00x + 4.045
# R^2值: 0.9544
# 加权均方误差：0.003365

# %% [markdown]
# ### 2.正则化
#
# 正则化可以用于处理特征矩阵不满秩的情况，更大的作用是在增强模型的泛化能力。我们这里只介绍L2正则化，更多内容在“过拟合”这一章讲。
#
# 目标函数：$J(\beta) = \frac{1}{2m}(Y-X\beta)^T(Y-X\beta)+\lambda\beta{\beta}^T$。
# 使这个函数值最小时，有$(X^TX+\lambda E)\beta = X^TY$。
# 可以看到，我们添加了一个数量矩阵。运用代数知识：$X^TX$是半正定矩阵<sup>1</sup>，$\lambda E$是正定矩阵，和就是正定矩阵，正定矩阵一定是可逆的<sup>2</sup>，即$(X^TX+\lambda E)$可逆。我们便求出了参数值。
#
# 以上只是代数的解释，下面从统计学角度讨论一下为什么要拿一个数量矩阵“冲淡”特征矩阵。当出现$X$非满秩时，意味着它有一列可以用其他列表示，由于一列代表同一个特征，也就是说某一个特征可以被其他特征表示，这种现象被称为**多重共线性**。由于一个特征可以表示为其他特征的线性回归，所以存在多重共线性的回归也学习了这个线性回归的误差项，模型无法突出样本与其背后总体的真正特征。而“冲淡”后，误差被抹平，特征还保存。所以加了一个数量矩阵。
#
# 再观察目标函数，由于同时要使前后两个项都尽可能地小，所以L2正则化会压低过大的参数，同样是避免特殊值带来的干扰。
#
# *如果读者了解过对模型的“假设检验”，会发现有趣的一点：目标函数的前一项是在尽量学习特征，表明线性关系的显著的；后一项以“所有参数都为零”为目标，这正好与线性关系不显著的零假设一致，同样可以作为对正则化增强泛化能力的理解。*
#
# <sup>1,2</sup>下面是对1,2的代数证明
# 1.$x^T(A^TA)x = (Ax)^T(Ax)$。由于$Ax$是n列向量，$(Ax)^T(Ax)$就是n个平方的和，大于等于0。
# 2.正定矩阵$A$与$E$合同，故可以表示为$A=B^TB$，其中$B$是可逆矩阵，所以$A$可逆。

# %% [markdown]
# ### 3.最小值搜索
#
# 最小值是一个庞大的课题，几乎在数据科学、机器学习的许多领域都有应用。我们只简要介绍其概念和几种常见方法。
#
# #### 1.最小值搜索的概念
# 机器学习中常常面临寻找一个函数的最小值的任务（找最大值加符号可以转化为找最小值），正如前面我们一直在寻找最小二乘法的最小值那样。这个函数有时被称为**损失函数**，均方误差$MSE=\frac{1}{n}\Sigma_{i=1}^n(y_i-\hat{y}_i)^2$就是一种损失函数。也有代价函数，它是基于损失函数的扩展。
# 最小值搜索也称为优化，分为无约束优化和有约束优化。无约束优化就是优化过程中没有任何限制条件，目标是找到最优解，使目标函数的值最小或最大。有约束优化则需要满足一定的约束条件，包括等式约束(参数必须满足某等式)和不等式约束。
#
# #### 2.绘制二维等高线图
# 二变量函数是多变量函数的基础，而它正好可通过绘制等高线图来可视化。这是一个非常有趣的技巧，也会给下面的梯度下降法提供灵感。
# 通过观察等高线，我们可以很快的找到极值点。虽然精度不足，但适合观察，这正是可视化的魅力。

# %%
import numpy as np
import matplotlib.pyplot as plt


def f(x, y):
    return x**2 + y**2 + x*y + 6*np.sin(x)


# 创建网格数据
x = np.linspace(-3, 5, 1000)  # 这里决定了图示的上下限和取点个数
y = np.linspace(-3, 3, 1000)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# 方法1.用线表示
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(2.5, 1.875), dpi=180)
contour = plt.contour(X,Y,Z,levels=12, linewidths=1, colors='k')  # “levels”是等高线个数
plt.clabel(contour, fontsize=9, colors=('k','r'))
plt.title('$f(x, y) = x^2 + y^2 + xy + 6sinx$ 函数等高线图', fontsize=7.5)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# 方法2.用颜色表示
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(4,3))
cset = plt.contourf(X,Y,Z,6,cmap=plt.cm.hot_r) #cmap后面的代码决定了颜色，查询https://matplotlib.org/2.0.2/users/colormaps.html以了解更多
plt.colorbar(cset)
plt.show()

# 方法3.线+颜色
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.figure(figsize=(4,3))
cset = plt.contourf(X,Y,Z,12,cmap=plt.cm.cool) 
contour = plt.contour(X,Y,Z,12,colors='k')
plt.clabel(contour,fontsize=10,colors='k')
plt.colorbar(cset)
plt.title('$f(x, y) = x^2 + y^2 + xy + 6sinx$ 等高线图')
plt.show()

# 方法4.我们也可以绘制三维图，但可读性不如等高线图
from mpl_toolkits.mplot3d import Axes3D


plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.sans-serif'] = ['SimHei']
fig = plt.figure(figsize=(9, 6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap='BuPu_r', edgecolor='none')
fig.colorbar(surf, shrink=0.65, aspect=15)
ax.set_title('$f(x, y) = x^2 + y^2 + xy + 6sinx$ 3D图')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()

# %% [markdown]
# #### 3.梯度下降法
#
# 关于这一方法的介绍参见https://blog.csdn.net/iqdutao/article/details/107174240
#
# 我们再补充介绍几种基本的方法和代码实现。
#
# **1.批量梯度下降法**
# 批量梯度下降是最原视最基本的方法，它每次迭代都会计算一遍总体的值。假设样本量为$N$，迭代次数为$S$，则要进行$N*S$次函数计算。这样的好处是可以综合所有样本，比较稳定，但计算量过大。下面演示固定学习率的批量梯度下降，并把将它多次迭代结果与解析解法比较。以下也会把损失函数的值叫做成本(cost)。

# %%
import numpy as np
import matplotlib.pyplot as plt


# 1. 最小二乘法目标函数
def compute_cost(X, y, theta):
    m = len(y)  # 样本数量
    predictions = X.dot(theta)  # 预测值
    cost = (1 / (2 * m)) * np.sum(np.square(predictions - y))  # 计算损失，相比最小二乘多除一个2是为了求导后式子系数为1
    return cost


# 2. 批量梯度下降法
def batch_gradient_descent(X, y, theta, learning_rate, n_iterations):
    m = len(y)  # 样本数量
    cost_history = np.zeros(n_iterations)  # 用于存储每次迭代的成本
    for iteration in range(n_iterations):
        gradients = (1 / m) * X.T.dot(X.dot(theta) - y)  # 计算梯度
        theta -= learning_rate * gradients  # 更新参数
        cost_history[iteration] = compute_cost(X, y, theta)  # 记录每次迭代的损失（1/2均方误差）
    return theta, cost_history

# 3. 生成数据和初始化参数
np.random.seed(42)  # 设置随机种子以确保结果可重复
X_1 = 2 * np.random.rand(100, 1) 
X_2 = 2 * np.random.rand(100, 1)
X_3 = 2 * np.random.rand(100, 1)
y = 4 + 3 * X_1 + 2*X_2 + 6*X_3 + np.random.randn(100, 1)
# 初始化参数
X_b = np.c_[np.ones((100, 1)),X_3, X_2, X_1]  # 添加偏置项（截距）
theta_initial = np.random.randn(4, 1)  # 随机初始化参数
learning_rate = 0.1 # 学习率，把它的值改到0.5有惊喜
n_iterations = 400  # 迭代次数

# 4.执行批量梯度下降
theta_optimal, cost_history = batch_gradient_descent(X_b, y, theta_initial, learning_rate, n_iterations)
print(f'估计的参数:\n{theta_optimal[::-1]}') #倒序是为了先输出斜率
print(f'第20次迭代成本:{cost_history[19]:.6f}')
print(f'第50次迭代成本:{cost_history[49]:.6f}')
print(f'第100次迭代成本:{cost_history[99]:.6f}')
print(f'第400次迭代成本: {cost_history[-1]:.6f}')

# 5.解析法验证
theta_best = np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y  
intercept, slope_3, slope_2, slope_1 = theta_best[0], theta_best[1], theta_best[2], theta_best[3]
print(f"\n用解析法算出的回归方程: y = {slope_1[0]:.2f}x_1 + {slope_2[0]:.2f}x_2 + {slope_3[0]:.2f}x_3 + {intercept[0]:.2f}")
cost = compute_cost(X_b, y, theta_best)
print(f'解析法的最优成本: {cost:.6f}')

# 6.绘制成本函数变化
plt.figure(figsize=(8, 6))
plt.plot(range(n_iterations), cost_history, 'b-', linewidth=2)
plt.title('梯度下降求目标函数的迭代次数-成本关系图')
plt.xlabel('迭代次数')
plt.ylabel('成本')
plt.show()

# %% [markdown]
# #### 可视化：步长对下降轨迹的影响
# 我们已经知道学习率(步长)对优化效果的重要性，前面的代码可以看到当步长过大时，损失函数的值甚至会变大。这里通过数据可视化直观地理解梯度下降法每次迭代的下降轨迹，以及改变步长对下降方向的影响。

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 一.进行梯度下降法
# 1.生成样本
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

#  2.损失函数
def compute_cost(X, y, theta):
    m = len(y)
    predictions = X.dot(theta)
    cost = (1 / (2 * m)) * np.sum(np.square(predictions - y))
    return cost


# 3.批量梯度下降法
def gradient_descent(X, y, theta, learning_rate, iterations):
    m = len(y)
    cost_history = []

    for i in range(iterations):
        gradients = (1 / m) * X.T.dot(X.dot(theta) - y)
        theta = theta - learning_rate * gradients
        cost = compute_cost(X, y, theta)
        cost_history.append({'k': theta[1, 0], 'b': theta[0, 0], 'cost': cost})
        
    return theta, cost_history

# 4.初始化
X_b = np.c_[np.ones((100, 1)), X]
initial_theta = [[1.5],[4.6]]  # 取这个数是因为震荡表现优良
learning_rate = 0.9  #重要参数，改变学习率（步长）的大小观察不同学习率对逼近速度影响，改为1有惊喜
iterations = 1000  #迭代次数

# 5.执行梯度下降
theta, cost_history = gradient_descent(X_b, y, initial_theta, learning_rate, iterations)
print(f'最优参数: k = {theta[1, 0]}, b = {theta[0, 0]}')
print(f'最优损失: {cost_history[-1]["cost"]}')
k_best = theta[1, 0]
b_best = theta[0, 0]
c_best = cost_history[-1]["cost"]

#  二.梯度下降法的可视化
# 1.将损失函数值和参数值记录到 DataFrame 中
df = pd.DataFrame(cost_history)
print(f'{df.head()}, \n{df.iloc[19]}') # iloc后面的取值记得跟从自此开始第5行n的取值，取n-1

# 2.创建三个列表并储存起始位置
k = 1 #步长为1
n = 20 #取20组
indices = range(0, k * n, k)
s_df = df.iloc[indices]
kl = s_df['k'].tolist()
bl = s_df['b'].tolist()
cl = s_df['cost'].tolist()
kl.insert(0,4.6)  # 这两行记得跟着initial_theta改参数
bl.insert(0,1.5)
c_0 = compute_cost(X_b,y,initial_theta)
cl.insert(0,c_0)

# 3.计算并绘制目标函数的等高线图
k_values = np.linspace(0, 6, 300)
b_values = np.linspace(0, 7, 300)
K, B = np.meshgrid(k_values, b_values)
costs = np.zeros(K.shape)

for i in range(K.shape[0]):
    for j in range(K.shape[1]):
        theta = np.array([[B[i, j]], [K[i, j]]])
        costs[i, j] = compute_cost(X_b, y, theta)

# 特别注意第二行的代码：等高线对数化，使高值处稀疏，低值处密集，实际并不是等高的。所以越到后面看起来越难前进，下降方向看起来不与等高线垂直。
plt.figure(figsize=(3.33, 2), dpi=200)
contour = plt.contour(K, B, costs, linewidths=0.9, levels=np.logspace(np.log10(costs.min()), np.log10(costs.max()), 20), cmap='jet')
cbar = plt.colorbar(contour)
cbar.ax.tick_params(labelsize=6)
plt.xlabel('斜率k', fontsize=8)
plt.ylabel('截距b', fontsize=8)
plt.title('损失函数等高线图', fontsize=8)
plt.scatter(kl, bl, color='black', label='迭代样本点',s=0.8, alpha=1.0)
plt.plot(kl, bl, color='#8B658B', linestyle='-', linewidth=0.8, label='下降方向')
plt.scatter(k_best, b_best, color='#FFC125',s=1, label='迭代最低点')
plt.legend(fontsize=5)
plt.show()

# 4.绘制3D图
from mpl_toolkits.mplot3d import Axes3D


plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.sans-serif'] = ['SimHei']
fig = plt.figure(figsize=(9, 6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(K, B, costs, cmap='BuPu_r', alpha=0.7)

cbar = fig.colorbar(surf, shrink=0.45, aspect=15)
cbar.ax.tick_params(labelsize=6)

ax.scatter(kl, bl, cl, color='black', s=0.6, alpha=1.0)
ax.scatter(k_best, b_best, c_best, color='#FFC125',edgecolor='b', s=1.2, alpha=1.0)
ax.plot(kl, bl, cl, color='b', linewidth=0.6,linestyle='-', alpha=1.0)

ax.set_title('$f(k, b) = \frac{1}{2}\Sigma(y_i-kx_i-b)^2$ 3D图',fontsize=12 )

ax.set_xlabel('k', fontsize=6, labelpad=1)  # 设置标签
ax.set_ylabel('b', fontsize=6, labelpad=1)
ax.set_zlabel('f', fontsize=6, labelpad=1)
ax.tick_params(axis='x', labelsize=6, pad=3)  # 设置刻度
ax.tick_params(axis='y', labelsize=6, pad=3)  
ax.tick_params(axis='z', labelsize=6, pad=3)  
plt.show()
# Out:
# 最优参数: k = 2.96846751070102, b = 4.222151077447228
# 最优损失: 0.49621932436232413
#           k         b      cost
# 0  5.115505  2.561455  1.330798
# 1  4.158591  2.228891  1.108295
# 2  4.541080  3.009996  0.945120
# 3  3.836579  2.762597  0.825453
# 4  4.120353  3.337408  0.737691,
# k       3.037964
# b       4.101470
# cost    0.498533
# Name: 19, dtype: float64

# %% [markdown]
# #### 进阶1.会学习的学习率
#
# 固定的学习率可能无法适应函数的实际情况。过大时，可能震荡，过小时，可能收敛缓慢。参见https://blog.csdn.net/shanglianlm/article/details/85143614 所介绍的6种学习率调整方法。下面展示指数衰减的python范例。

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# 一.进行梯度下降法
# 1.生成样本
np.random.seed(5)
X = 2 * np.random.rand(100, 1)
y = 4 + (-2.5) * X + 0.8*np.random.randn(100, 1)

#  2.损失函数
def compute_cost(X, y, theta):
    m = len(y)
    predictions = X.dot(theta)
    cost = (1 / (2 * m)) * np.sum(np.square(predictions - y))
    return cost


# 3.批量梯度下降法
def gradient_descent(X, y, theta, learning_rate, iterations):
    m = len(y)
    cost_history = []

    for i in range(iterations):
        gradients = (1 / m) * X.T.dot(X.dot(theta) - y)
        theta = theta - learning_rate * gradients
        cost = compute_cost(X, y, theta)
        cost_history.append({'k': theta[1, 0], 'b': theta[0, 0], 'cost': cost})
        
    return theta, cost_history

# 4.更新学习率的梯度下降法
def gradient_descent_new(X, y, theta, initial_learning_rate, iterations, decay_rate=0.01):
    m = len(y)
    cost_history = []

    for i in range(iterations):
        learning_rate = initial_learning_rate * np.exp(-decay_rate * i)
        gradients = (1 / m) * X.T.dot(X.dot(theta) - y)
        theta = theta - learning_rate * gradients
        cost = compute_cost(X, y, theta)
        cost_history.append({'k': theta[1, 0], 'b': theta[0, 0], 'cost': cost})
        
    return theta, cost_history

# 5.初始化
X_b = np.c_[np.ones((100, 1)), X]
initial_theta = [[1.8],[3.8]]  # 取这个数是因为震荡表现优良
learning_rate = 0.87  #重要参数，改变学习率（步长）的大小观察不同学习率对逼近速度影响，改为1有惊喜
iterations = 200  #迭代次数

# 6.执行梯度下降
theta, cost_history = gradient_descent(X_b, y, initial_theta, learning_rate, iterations)
print(f'最优参数: k = {theta[1, 0]}, b = {theta[0, 0]}')
print(f'最优损失: {cost_history[-1]["cost"]}')
k_best = theta[1, 0]
b_best = theta[0, 0]
c_best = cost_history[-1]["cost"]

theta_new, cost_history_new = gradient_descent_new(X_b, y, initial_theta, learning_rate, iterations)
print(f'最优参数(学): k_new = {theta[1, 0]}, b_new = {theta[0, 0]}')
print(f'最优损失(学): {cost_history[-1]["cost"]}')
k_new_best = theta_new[1, 0]
b_new_best = theta_new[0, 0]
c_new_best = cost_history_new[-1]["cost"]

#  二.梯度下降法的可视化
# 1.将损失函数值和参数值记录到 DataFrame 中
df = pd.DataFrame(cost_history)
print(f'{df.head()}, \n{df.iloc[19]}') # iloc后面的取值记得跟从自此开始第5行n的取值，取n-1
df_new = pd.DataFrame(cost_history_new)
print(f'{df_new.head()}, \n{df_new.iloc[19]}')

# 2.创建三个列表并储存起始位置
def canshudian(k, n, df, k_0, b_0, X_b, y, initial_theta):
    # k是步长，n是个数
    indices = range(0, k * n, k)
    s_df = df.iloc[indices]
    kl = s_df['k'].tolist()
    bl = s_df['b'].tolist()
    cl = s_df['cost'].tolist()
    kl.insert(0,k_0)  
    bl.insert(0,b_0)
    c_0 = compute_cost(X_b,y,initial_theta)
    cl.insert(0,c_0)
    return kl, bl, cl

k_0, b_0 = initial_theta[1][0], initial_theta[0][0]  # 选择初始值
kl, bl, cl = canshudian(1,20,df,k_0,b_0,X_b,y,initial_theta)
kl_new, bl_new, cl_new = canshudian(1,20,df_new,k_0,b_0,X_b,y,initial_theta)

# 3.计算并绘制目标函数的等高线图
k_values = np.linspace(-5, 4, 300)
b_values = np.linspace(-3, 6, 300)
K, B = np.meshgrid(k_values, b_values)
costs = np.zeros(K.shape)

for i in range(K.shape[0]):
    for j in range(K.shape[1]):
        theta = np.array([[B[i, j]], [K[i, j]]])
        costs[i, j] = compute_cost(X_b, y, theta)

# 特别注意第二行的代码：等高线对数化，使高值处稀疏，低值处密集，实际并不是等高的。所以越到后面看起来越难前进，下降方向看起来不与等高线垂直。
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.figure(figsize=(3.33, 2), dpi=200)
contour = plt.contour(K, B, costs, linewidths=0.9, levels=np.logspace(np.log10(costs.min()), np.log10(costs.max()), 20), cmap='jet')
cbar = plt.colorbar(contour)
cbar.ax.tick_params(labelsize=6)
plt.xlabel('斜率k', fontsize=8)
plt.ylabel('截距b', fontsize=8)
plt.title('损失函数等高线图', fontsize=8)

plt.scatter(kl, bl, color='black', label='迭代样本点',s=0.8, alpha=1.0)
plt.plot(kl, bl, color='#8B658B', linestyle='-', linewidth=0.8, label='下降方向', alpha=0.7)

plt.scatter(kl_new, bl_new, color='b', label='迭代样本点(学)',s=0.8, alpha=1.0)
plt.plot(kl_new, bl_new, color='#8B6969', linestyle='-', linewidth=0.8, label='下降方向（学)')

plt.scatter(k_best, b_best, color='#FFC125',s=1, label='迭代最低点')
plt.legend(fontsize=5)
plt.show()
# Out:
# 最优参数: k = -2.543074381452088, b = 4.074593206268179
# 最优损失: 0.34350827078356305
# 最优参数(学): k_new = -2.543074381452088, b_new = 4.074593206268179
# 最优损失(学): 0.34350827078356305
#           k         b       cost
# 0 -1.620502 -1.652500  12.111233
# 1  2.211778  2.540098   9.432999
# 2 -1.997556 -0.196337   7.369493
# 3  1.025842  3.052260   5.778264
# 4 -2.244448  0.885727   4.550223,
# k      -2.166100
# b       4.077065
# cost    0.439300
# Name: 19, dtype: float64
#           k         b       cost
# 0 -1.620502 -1.652500  12.111233
# 1  2.173646  2.498381   9.120698
# 2 -1.873906 -0.116289   6.664042
# 3  0.854233  2.865966   4.737747
# 4 -1.943037  1.081288   3.296057,
# k      -2.329340
# b       3.826879
# cost    0.352577
# Name: 19, dtype: float64

# %% [markdown]
# #### 4.其他方法
#
# **1.牛顿法**。它在梯度下降法的基础上引入二阶导数的使用，需要更大的算力但逼近速度更快。
# **2.动量法**。它在梯度下降法的基础上引入动量，考虑过去的梯度，加快收敛速度。
# 此外还有演化算法、模拟退火等等。

# %% [markdown]
# ## 3.评估验证
#
# 在正式得出模型的参数后，我们要根据这些参数反推模型是否符合线性关系的假设；利用参数检验一些针对模型的假设；比较模型之间哪个更合适；比较简化模型与原模型差别是否显著。
# **这一部分主要是对模型的和对参数的两方面**。原来想这么分成两个板块，但两者互有交错，故从简单到复杂的逻辑来讲。
#
# ### 1.参数的置信区间与t检验(参)
# 前面已经用代码演示过怎么得出参数的标准误和置信区间。这里来看看怎么数学推导处参数的标准误。
# 设 $\varepsilon = \begin{pmatrix} \varepsilon_1 \\ \varepsilon_2 \\ ... \\ \varepsilon_n \end{pmatrix},  D(\varepsilon) = \sigma^2, (X^TX)^{-1}X^T = \begin{pmatrix} a_{11} & a_{12} & ... & a_{1n} \\ a_{21} & a_{22} & ... & a_{2n} \\ ...&...&...&... \\ a_{s1} & a_{s2} & ... & a_{sn} \end{pmatrix}$
# $\beta = (X^TX)^{-1}X^TY = (X^TX)^{-1}X^T(X\beta+\varepsilon) = \beta + (X^TX)^{-1}X^T \varepsilon $。β是一个常量，相当于求后者的方差，即求一个s维列向量各元素的方差。以第一列为例：
# $D(\Sigma_{i=1}^n a_{1i}\varepsilon_i) = E((\Sigma_{i=1}^n a_{1i}\varepsilon_i)^2) - E(\Sigma_{i=1}^n a_{1i}\varepsilon_i)^2 $
# 由于$E(\varepsilon_i) = 0$
# $D(\Sigma_{i=1}^n a_{1i}\varepsilon_i) = E((\Sigma_{i=1}^n a_{1i}\varepsilon_i)^2) = E(\Sigma_{i=1}^n\Sigma_{j=1}^n a_{1i}a_{1j}\varepsilon_i\varepsilon_j) = \Sigma_{i=1}^n\Sigma_{j=1}^nE(a_{1i}a_{1j}\varepsilon_i\varepsilon_j)$
# 由于残差项相互独立$E(\varepsilon_i\varepsilon_j) = E(\varepsilon_i)E(\varepsilon_j) = 0, i\not=j$
# $D(\Sigma_{i=1}^n a_{1i}\varepsilon_i) = \Sigma_{i=1}^nE(a_{1i}^2{\varepsilon_i}^2) = \Sigma_{i=1}^na_{1i}^2E({\varepsilon_i}^2) = \Sigma_{i=1}^na_{1i}^2D(\varepsilon_i) = \Sigma_{i=1}^na_{1i}^2\sigma^2$
# 这就是最终结果。
# 我们可以算一下简单线性回归的参数方差
# $(X^TX)^{-1}X^T = \frac{1}{n(\Sigma x_i^2 - n\bar{x}^2)}\begin{pmatrix} n(x_1-\bar{x}) & n(x_2-\bar{x}) & ... & n(x_n-\bar{x}) \\ \Sigma x_i^2-n\bar{x}x_1 & \Sigma x_i^2-n\bar{x}x_2 & ... & \Sigma x_i^2-n\bar{x}x_n \end {pmatrix}$
# 得$D(k) = \frac{\sigma^2}{\Sigma x_i^2 - n\bar{x}^2}, D(b) = \frac{\Sigma x_i^2}{n(\Sigma x_i^2-n\bar{x}^2)}\sigma^2$
# 再求$\sigma^2 = \frac{\Sigma(y_i - \hat{y_i})^2}{n-s}$，s是包括截距项在内的参数个数。
# #### t检验
# 利用前面求得的均值和方差，**使用t分布计算置信区间，自由度为n-s**。因为这里用的是样本方差估计总体方差。
# t检验的原假设通常是“参数$k_i$为0”，当然0也可以为需要验证的其他值。只要看一下0在不在参数值的置信区间，如果不在，就拒绝；如果在，说明没有充分理由认为参数不能为零。对后一种情况就要考虑该参数是否对响应变量产生了线性影响。
#
# ### 2.对模型假设的验证(模)
#
# 在得到模型后，可以检验模型的前提假设。如果该模型是真实模型的无偏估计 $\Rightarrow$ 那么在一定的置信度内，应该满足假设。所以如果有无法满足的假设，则有理由不接受该模型。对于线性回归模型，前面给出了**1.满秩；2.线性关系存在；3.误差项独立地服从期望为零的同方差正态分布；4.自变量与误差项相互独立**的前提。1已解决。4叫做“未观察到的异质性”，也就是有参数没有被添加到模型中，这一现象比较难发现，我们放在最后的模型诊断部分。
#
# #### 线性关系存在的检验
# **F检验**：如果线性关系不存在，那么所有除截距项以外的系数都应该为零，那么零假设$H_0: k_1 = k_2 = ... = k_s = 0$。此时回归平方和$SSR=\Sigma (\hat{y_i} - \bar{y_i})^2$的期望为0，是一个极小值；残差平方和$SSE=\Sigma (y_i-\hat{y_i})^2$的期望为$nD(y)$，是一个极大值(只要回归了就不可能比这个数还大)。根据前面所学，服从正态分布的两统计量的方差比服从F-分布，所以统计量$S = \frac{\frac{SSR}{s}}{\frac{SSE}{n-s-1}}$服从F-分布(除的俩数是自由度)。线性关系越强，SSE就会越大，SSR就会越小，所以统计量越大，p值越小。
#
# #### 误差项期望为零的正态分布和同方差分布的检验
# 这里包括了三项检验，首先是期望为零。实际上，按照解析法求出的回归方程，其残差项的期望一定为零：
# $\beta = (X^TX)^{-1}X^TY, \hat{Y} = X\beta \Rightarrow \hat{Y} = X(X^TX)^{-1}X^TY \Rightarrow X^T\hat{Y} = X^TX(X^TX)^{-1}X^TY \Rightarrow X^T(Y-\hat{Y}) = 0$。由于矩阵$X^T$有一行是截距项，全为1，故$\Sigma (y_i - \hat{y_i})$。
# **正态性**：
# 最直接的方法就是画残差的直方图，观察是否接近钟形曲线。或绘制Q-Q图，将残差的分位数与标准正态分布的分位数进行比较，观察是否大致沿y=x分布。最开始也给出了检验正态性的python方法。
# **同方差性**：
# 可绘制残差对预测值的散点图，观察残差的分布是否均匀。同样也有机器检验法，基于假设检验:方差是常数。

# %%
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.stats.diagnostic import het_white


residuals = model.resid  # 残差计算
# Breusch-Pagan 检验
test_stat, p_value, f_stat, f_p_value = het_breuschpagan(residuals, model.model.exog)
print(f'Breusch-Pagan Test的t值: {test_stat}, p-value: {p_value}')
# White 检验
test_stat, p_value, f_stat, f_p_value = het_white(residuals, model.model.exog)
print(f'White Test的t值: {test_stat}, p-value: {p_value}')
# Out:
# Breusch-Pagan Test的t值: 0.06972522228533284, p-value: 0.7917372767740005
# White Test的t值: 0.5988218590187833, p-value: 0.7412547433931275

# %% [markdown]
# ### 3.交叉验证(模)
#
# #### 评判回归的重要指标：拟合与泛化
# 回归模型是基于在样本上拟合效果最好的目的建立的。但我们始终担心我们使用的样本相对总体有多大的偏差，对训练样本拟合数据过好，反而舍本逐末，无法很好地拟合总体特征。这个问题叫做**过拟合**。一个模型需要在另一组样本中进行检验，评估其在其他模型上的拟合能力，才能说它拟合性能优良。我们把一个模型对其他样本的拟合能力叫做**泛化能力**。增强泛化能力是一个重要目标，前面略略提过的正则化以抹平噪声是一个方法。
#
# 到目前为止，我们都是从模型自己去评判模型，没有外部数据来评估模型，既当运动员又当裁判。如果能搞到一组样本用于检验模型那就太好了。如果检验出来模型不好呢，正好可以用原来用于检验的样本建模，原来用于建模的样本检验，选择表现更好的那一个。基于这个愿望，我们有了交叉验证的方法。
#
# **k折交叉验证**：把样本划分为k个数据集，把其中k-1个作为训练集，1个作为测试集。每个数据集都作一次测试集，得到k个模型和测试成绩。这样，我们可以
# 1.评估模型的泛化能力，避免过拟合。
# 2.选择适合的模型，综合模型的拟合数据和泛化数据。
# 3.选择最佳的超参数。超参数是学习前调整的参数，比如正则化的$\lambda$。选择k种不同的超参数组合(说“组合”是因为有时候超参数不止一个)，每次训练并测试一种组合，选择性能最佳的超参数组合。
# 注意！k折交叉验证相当于在原始样本中抽样出测试样本，也要遵循抽样技术所要求的分层原则。每种类别的样本数据要按原比例分配。
#
# 下面演示k折交叉验证的代码

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.datasets import load_diabetes


data = load_diabetes()
X = data.data
y = data.target

# K折交叉验证
k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=42)  # 42是宇宙的终极答案。这个种子确保每次结果一致。

model = LinearRegression()
mse_list = []

# 进行K折交叉验证
for fold, (train_index, test_index) in enumerate(kf.split(X), 1):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    model.fit(X_train, y_train)  # 训练
    y_pred = model.predict(X_test)  # 预测
    mse = mean_squared_error(y_test, y_pred)  #评估
    mse_list.append(mse)
    
    # 打印回归系数、截距和均方误差
    print(f"Fold {fold}, MSE: {mse:.4f}")

# 输出平均均方误差
print(f"Mean MSE: {np.mean(mse_list):.4f}")
# Out:
# Fold 1, MSE: 2900.1936
# Fold 2, MSE: 2662.6376
# Fold 3, MSE: 3312.3059
# Fold 4, MSE: 2797.8836
# Fold 5, MSE: 3403.8878
# Mean MSE: 3015.3817

# %% [markdown]
# ### 4.回归指标(模)
#
# 前面讲了很多“操作性”的方法，其中的许多都需要用到各种“指标性”的工具。这里予以讲解。
# 正如前面所说的，回归的目的是增强对数据集的拟合能力，泛化能力也是对测试数据集的拟合能力。所以回归的指标所衡量的都是响应变量的预测值与实际值的差有多大，并希望它越小越好。
# #### 1.均方误差MSE
# MSE是出场频率最高的指标，计算式为$MSE=\frac{1}{n}\Sigma(y_i - \hat{y_i})^2$。对其开方，得均方根误差$RMSE=\sqrt{MSE}$，使单位一致。
# #### 2.加权均方误差WMSE
# 因为样本可靠性或代表性的不同，需要对不同的样本加权，我们用加权均方误差衡量加权线性回归的拟合度。$WMSE=\frac{\Sigma w_i(y_i-\hat{y_i})^2}{\Sigma w_i}$。这里加的权重应与加权回归中的权重保持一致。
# #### 3.决定系数$R^2$
# 先记住一下几个简写:
# 残差平方和$SSE = \Sigma(y_i - \hat{y_i})^2$
# 总平方和$SST = \Sigma(y_i - \bar{y})^2$
# 回归平方和$SSR = \Sigma(\hat{y_i} - \bar{y})^2$
# $R^2 = 1 - \frac{SSE}{SST} = \frac{SSR}{SST}$。这个量描述的是模型对数据变异性的解释程度，越大说明解释程度越高。
# 这里证明一下$SSR + SSE = SST$
# $SST = \Sigma(y_i - \hat{y_i} + \hat{y_i} - \bar{y})^2 = \Sigma(y_i - \hat{y_i})(\hat{y_i} - \bar{y}) + SSE + SSR$
# $\Sigma(y_i - \hat{y_i})(\hat{y_i} - \bar{y}) = \Sigma e_i(\hat{\beta}X_i - \hat{\beta}\bar{X}) = \hat{\beta}\Sigma e_iX_i + \hat{\beta}\Sigma e_i\bar{X} = n\hat{\beta}E(e_iX_i) + n\hat{\beta}\bar{X}E(e_i) = 0$

# %% [markdown]
# ### 5.考虑极端数据的检验与模型对比(模)
# #### 极端数据
# 极少数数据由于测量错误或个体性差异，极端地偏离了模型的趋势。对于这一类数据，应当尽量削减其影响。而“平方和”的形式则会放大这些数据，所以可以考虑把平方换成绝对值。
# **平均绝对误差**$MAE = \frac{1}{n} \Sigma \lvert y_i - \hat{y_i} \rvert$。优点是对异常值不敏感。
# **平均绝对百分比误差**$MAPE = \frac{1}{n} \Sigma \lvert \frac{y_i - \hat{y_i}}{y_i} \rvert * 100%$。一个优点是大误差通常对应大$y_i$值，可以进一步降低对异常值的敏感度。其二是“标准化”，把绝对的误差值变为相对样本数据值的误差值，百分数的形式更易于解读。
#
# #### 模型对比
# 模型之间的对比点是拟合能力，且不仅仅是对已有数据的拟合能力，这不足以说明模型对总体中的其他数据有近似的拟合能力。通常而言，在超过一个阈值后，模型的参数越多，越容易过拟合。把参数的个数保持在一个合理的数量，才能确保其泛化能力。所以把模型对已有数据的拟合能力和对参数过多的量化惩罚两者结合，构造出新的回归指标。
#
# **adjusted R^2**:$Adjusted R^2 = 1 - (1 - R^2)*\frac{n - 1}{n - p - 1} = 1 - \frac{SSE}{SST}*\frac{n - 1}{n - p - 1}$。p(参数个数)越大，指标值就越小。
#
# **赤池信息准则**:$AIC = -2lnL + 2k$ 其中，L是似然函数值，k是参数个数。AIC的值越小越好，即参数越少，似然函数值越大越好。下面求线性回归函数的似然函数
# $L = \Pi \frac{1}{2\pi \sigma^2} exp(-\frac{(y_i - X_i\beta)^2}{2\sigma^2})$
# $-2lnL = nln(2\pi \sigma^2) + \frac{1}{\sigma^2}\Sigma (y_i-X_i\beta)^2$
# 当似然函数最小时，取$\beta$为$\hat{\beta}$，误差项的方差$\hat{\sigma}^2 = \frac{1}{n} \Sigma(y_i - X_i\hat{\beta})^2 = MSE$带入后省去不承载信息的两个常数$2\pi$和第二个式子化简出的1。$AIC = nln(MSE) + 2k$。
# **贝叶斯信息准则**:$BIC = -2lnL + klnn$。这一算法对参数数量的惩罚更为严格。通常来说，样本越大，变异性越强，越容易找出更多的参数，所以构造第二个项在样本很大的时候限制参数的增长。
#
# **似然比检验**:$\Lambda = -2ln(\frac{L_1}{L_0})$。这个式子可以看作是AIC的差，通过似然性的比值比较模型间的拟合差异。一般来说，$L_0$是在已有样本上表现较好的模型，或者原始模型，$L_1$是表现稍弱，或简化模型。作零假设两模型的拟合效果相同，通过服从卡方分布的统计量$\Lambda$的值判断两个模型的拟合效果是否存在差异。

# %% [markdown]
# ### 6.参数选择(参)
#
# 前面我们已经讨论过参数过多的问题。那么，什么样的参数可以予以删去，而什么参数必须保留呢？
# #### 以前进选择为例
# 从零开始添加参数。每添加一次，就把新的模型与原来的模型进行比较，比较依据为AIC等指标。如果不显著的话就认为该参数的解释性不强，不添加这个参数。
# 如果采用AIC(BIC同理)作为指标，则是每添加一次，比较AIC的大小，变小了就加上，没变小就不加，然后下一个。
# 如果采用p值作为指标，则是每添加一次，计算所有参数的p值，如果p>0.05或置信区间包含0，都认为该参数不显著，不加入。
# 后退同理，从一个包含所有候选参数的模型开始减。

# %% [markdown]
# ## 模型扩展
#
# ### 1.多重共线性
